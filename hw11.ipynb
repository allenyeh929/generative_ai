# %% [markdown]
# <a href="https://colab.research.google.com/github/allenyeh929/generative_ai/blob/main/hw11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 64.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.18.0
#     Uninstalling pygit2-1.18.0:
#       Successfully uninstalled pygit2-1.18.0
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Total 6725 (delta 0), reused 0 (delta 0), pack-reused 6725 (from 1)
# Receiving objects: 100% (6725/6725), 33.33 MiB | 10.00 MiB/s, done.
# Resolving deltas: 100% (3854/3854), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# ...

# %% [markdown]
# ## 結果展示
# ### 應用情境 ：萬聖節社區活動
#
# #### prompt 1 : "A cute cartoon calf mascot in a pumpkin costume holding a 'Trick or Treat' basket, surrounded by kids in costumes. The background shows a decorated community center with jack-o'-lanterns, ghosts, and candy. Pop art style, festive and colorful."
#
# ![pumpkin.png](data:image/png;base64,...)

# %% [markdown]
# #### prompt 2 : "A smiling cartoon calf dressed as a wizard with a starry cape and wand, floating candies around magically. Children are laughing and reaching for candy. The background features a full moon, bats, and haunted house decorations. Pop art style, fun and spooky."
#
# ![cow.png](data:image/png;base64,...)
